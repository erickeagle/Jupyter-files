# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs

# %%
X,y  = make_blobs(n_samples=500,n_features=2,centers=6,random_state=7)

# %%
plt.figure(0)
plt.grid(True)
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
k = 6

color  = ["green","red","blue","yellow","orange","pink"]

clusters = {}

for i in range(k):
    center = 10*(2*np.random.random((X.shape[1],))-1)
    points = []
    
    cluster = {
        'center':center,
        'points':points,
        'color': color[i]
        }
    
    clusters[i] = cluster

# %%
clusters
# Out:
# {0: {'center': array([ 0.46088889, -0.44138109]),
#   'points': [],
#   'color': 'green'},
#  1: {'center': array([ 7.72018219, -7.94442713]),
#   'points': [],
#   'color': 'red'},
#  2: {'center': array([-1.01453636,  9.54707513]),
#   'points': [],
#   'color': 'blue'},
#  3: {'center': array([ 6.20201889, -5.20523666]),
#   'points': [],
#   'color': 'yellow'},
#  4: {'center': array([7.23195255, 4.54107543]),
#   'points': [],
#   'color': 'orange'},
#  5: {'center': array([3.5162477 , 8.51977861]), 'points': [], 'color': 'pink'}}

# %%
def distance(v1,v2):
    return np.sqrt(np.sum((v1-v2)**2))

# %%
# Assign every data point to one of the clusters
def assignPointToClusters(clusters): #E-Step
    for ix in range(X.shape[0]):
        dist = []
        curr_x = X[ix]

        for kx in range(k):
            d = distance(curr_x,clusters[kx]['center'])
            dist.append(d)

        current_cluster = np.argmin(dist)    
        clusters[current_cluster]['points'].append(curr_x)

def updateClusters(clusters): # M-Step -> We update every cluster center according to the mean of the points in it
    for kx in range(k):
        pts = np.array(clusters[kx]['points'])
        
        if pts.shape[0]>0: #If a cluster has some-nonzero points
            new_u = pts.mean(axis=0)
            clusters[kx]['center'] = new_u
            clusters[kx]['points'] = [] #Clear the list 
                    
    

def plotClusters(clusters):
    
    for kx in range(k):
        #print(len(clusters[kx]['points']))
        
        pts = np.array(clusters[kx]['points'])
        #print(pts.shape)
        
        #Plot the points
        try:
            plt.scatter(pts[:,0],pts[:,1],color=clusters[kx]['color'])
        except:
            pass
        
        #Plot the cluster center
        uk = clusters[kx]['center']
        plt.scatter(uk[0],uk[1],color="black",marker="*")

# %%
plotClusters(clusters)

# %%
# Repeat this cell few times or put it inside a loop
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
