# %%
import numpy as np
import pandas as pd

# %%
data_train= pd.read_csv("house_Train_data.csv")
data_test= pd.read_csv("house_Test_data.csv")
import matplotlib.pyplot as plt

# %%
#Using Pearson Correlation
plt.figure(figsize=(25,25))
cor = data_train.corr()
sns.heatmap(cor, annot=True,cmap="RdYlGn")
plt.show()

# %%
cor_target = abs(cor["SalePrice"])
print((cor_target))
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# Id               0.028616
# MSSubClass       0.085299
# LotFrontage      0.364208
# LotArea          0.264500
# OverallQual      0.796618
# OverallCond      0.081109
# YearBuilt        0.528573
# YearRemodAdd     0.521432
# MasVnrArea       0.481024
# BsmtFinSF1       0.391743
# BsmtFinSF2       0.004139
# BsmtUnfSF        0.225371
# TotalBsmtSF      0.640040
# 1stFlrSF         0.614616
# 2ndFlrSF         0.326312
# LowQualFinSF     0.031600
# GrLivArea        0.729226
# BsmtFullBath     0.218421
# BsmtHalfBath     0.020676
# FullBath         0.561922
# HalfBath         0.306366
# BedroomAbvGr     0.168245
# KitchenAbvGr     0.136156
# TotRmsAbvGrd     0.558160
# Fireplaces       0.464889
# GarageYrBlt      0.496481
# GarageCars       0.652035
# GarageArea       0.636605
# WoodDeckSF       0.322062
# OpenPorchSF      0.325119
# EnclosedPorch    0.113269
# 3SsnPorch        0.007575
# ScreenPorch      0.134966
# PoolArea         0.012566
# MiscVal          0.038619
# ...

# %%
len(relevant_features)
# Out:
# 11

# %%
['OverallQual','YearBuilt','YearRemodAdd','TotalBsmtSF','1stFlrSF','GrLivArea','FullBath','TotRmsAbvGrd','GarageCars','GarageArea']
# Out:
# ['OverallQual',
#  'YearBuilt',
#  'YearRemodAdd',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  'GrLivArea',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'GarageCars',
#  'GarageArea']

# %%
X=data_train[['OverallQual','YearBuilt','YearRemodAdd','TotalBsmtSF','1stFlrSF','GrLivArea','FullBath','TotRmsAbvGrd','GarageCars','GarageArea']]

# %%
Y=data_train['SalePrice']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 10 columns):
# OverallQual     1100 non-null int64
# YearBuilt       1100 non-null int64
# YearRemodAdd    1100 non-null int64
# TotalBsmtSF     1100 non-null int64
# 1stFlrSF        1100 non-null int64
# GrLivArea       1100 non-null int64
# FullBath        1100 non-null int64
# TotRmsAbvGrd    1100 non-null int64
# GarageCars      1100 non-null int64
# GarageArea      1100 non-null int64
# dtypes: int64(10)
# memory usage: 86.1 KB
